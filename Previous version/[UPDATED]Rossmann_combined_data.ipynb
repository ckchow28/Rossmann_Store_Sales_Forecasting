# %%
import pandas as pd


sales_df = pd.read_csv("data/Rossmann_store.csv", low_memory = False)
store_df = pd.read_csv("data/Rossmann_train.csv", low_memory = False)

combined_df = pd.merge(sales_df, store_df, on='Store')
combined = combined_df.dropna()

# %%
combined_sorted = combined.sort_values(by='Sales', ascending = False)
combined_sorted
# Out:
#          Store StoreType Assortment  CompetitionDistance  \
# 237048     261         d          c              15340.0
# 114899     126         d          a               3370.0
# 457525     502         a          a                220.0
# 236684     261         d          c              15340.0
# 936355    1027         a          c                190.0
# ...        ...       ...        ...                  ...
# 579914     636         c          a                720.0
# 579907     636         c          a                720.0
# 579900     636         c          a                720.0
# 579893     636         c          a                720.0
# 1013440   1111         a          a               1900.0
#
#          CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 237048                         4.0                    2015.0       1
# 114899                        10.0                    2014.0       1
# 457525                         2.0                    2002.0       1
# ...

# %%
top_20_percent_index = int(len(combined_sorted) * 0.2)
top_20_percent_sales = combined_sorted.head(top_20_percent_index)
top_20_percent_sales
# Out:
#         Store StoreType Assortment  CompetitionDistance  \
# 237048    261         d          c              15340.0
# 114899    126         d          a               3370.0
# 457525    502         a          a                220.0
# 236684    261         d          c              15340.0
# 936355   1027         a          c                190.0
# ...       ...       ...        ...                  ...
# 862524    947         a          a                460.0
# 790794    868         d          c               1360.0
# 551753    605         d          a              10310.0
# 494033    542         a          a               7280.0
# 343154    377         a          c                100.0
#
#         CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 237048                        4.0                    2015.0       1
# 114899                       10.0                    2014.0       1
# 457525                        2.0                    2002.0       1
# ...
